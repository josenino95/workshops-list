# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import yaml

# %%
# Get table of past workshops
pastw = requests.get("https://ucsbcarpentry.github.io/past-workshops/").text
soup = BeautifulSoup(pastw, 'html.parser')

# %%
# Search tables in the data
table = soup.find('table')

# %%
wlist = []
for row in table.tbody.find_all("tr"):
    columns = row.find_all("td")
    for td in columns:
        if td.a:
            wlist.append({'href': td.a.get('href'), 'title_home': ' '.join(td.a.text.split())})

# %%
for w in wlist:
    if w['href'].rsplit('/')[1] == 'workshop':
        filename = '-'.join(w['href'].rsplit('/')[2:6])
        md_filename = filename[:-4] + 'md'
        wsite = 'https://raw.githubusercontent.com/UCSBCarpentry/ucsbcarpentry.github.io/main/_posts/' + md_filename
        wtext = requests.get(wsite).text
        w['date'] = filename[:10]
        try:
            instructors = re.search(r'instructors:\s(.+)', wtext).group(1).split(', ')
            helpers = re.search(r'helpers:\s(.+)', wtext).group(1).split(', ')
            w['instructors'] = instructors
            w['helpers'] = helpers
        except AttributeError:
            w['instructors'] = []
            w['helpers'] = []
    elif w['href'].rsplit('/')[2].endswith('github.io'):
        try:
            github = re.search(r'https://(.*?)\.github\.io', w['href']).group(1)
            page = w['href'].rsplit('/')[-2]
            website = 'https://raw.githubusercontent.com/' + github + '/' + page + '/gh-pages/index'
            wtext = requests.get(website + '.md').text
            if wtext == '404: Not Found':
                wtext = requests.get(website + '.html').text
            w['date'] = str(yaml.safe_load(wtext.strip().split('---\n')[1]).get('startdate', []))
            w['instructors'] = yaml.safe_load(wtext.strip().split('---\n')[1]).get('instructor', [])
            w['helpers'] = yaml.safe_load(wtext.strip().split('---\n')[1]).get('helper', [])
        except AttributeError:
            w['date'] = []
            w['instructors'] = []
            w['helpers'] = []
    else:
        print('error')

# %%
wlist
# Out:
# [{'href': '/workshop/2025/02/25/ucsb-ml.html',
#   'title_home': 'Introduction to Machine Learning in Python',
#   'date': '2025-02-25',
#   'instructors': ['Ronald Lencevičius', 'Jose Niño Muriel'],
#   'helpers': ['Arieanna Balbar', 'Jay Chi', 'Julien Brun']},
#  {'href': '/workshop/2025/02/18/ucsb-intermediater.html',
#   'title_home': 'Intermediate R',
#   'date': '2025-02-18',
#   'instructors': ['Sigrid Van Den Abeele', 'Jose Niño Muriel'],
#   'helpers': ['Ronald Lencevičius', 'Seth Erickson']},
#  {'href': '/workshop/2025/02/05/ucsb-containers.html',
#   'title_home': 'Container-driven Reproducible Research Made Simple',
#   'date': '2025-02-05',
#   'instructors': ['Ronald Lencevičius'],
#   'helpers': ['Seth Erickson',
#    'Jose Niño Muriel',
#    'Sang-Yun Oh',
#    'Kinji Leslie']},
#  {'href': '/workshop/2025/02/03/ucsb-computing.html',
#   'title_home': 'Research Computing - What to do when your work gets too big for your laptop',
#   'date': '2025-02-03',
#   'instructors': ['Brian Emery',
#    'Jay Chi',
#    'Jose Niño Muriel',
#    'Seth Erickson'],
#   'helpers': ['pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_1zu1a9eHmqQPR9c"']},
#  {'href': '/workshop/2025/01/23/ucsb-geospatial.html',
#   'title_home': 'Working with Geospatial Data in R',
#   'date': '2025-01-23',
#   'instructors': ['Jon Jablonski',
#    'Allie Caughman',
#    'Sigrid Van Den Abeele',
#    'Kristi Liu'],
#   'helpers': ['Arieanna Balbar', 'Jose Nino Muriel', 'Scott Miller']},
#  {'href': '/workshop/2025/01/14/ucsb-python.html',
#   'title_home': 'Introduction to Data Analysis with Python',
#   'date': '2025-01-14',
#   'instructors': ['Jose Niño Muriel', 'Jairo Melo-Flórez', 'Seth Erickson'],
#   'helpers': ['Tess Ivinjack',
#    'Sigrid Van Den Abbeele',
#    'Greg Janée',
#    'Jean Allen']},
#  {'href': '/workshop/2024/11/12/ucsb-qualdatanalysis.html',
#   'title_home': 'Handling and Sharing Qualitative Data Responsibly and Effectively',
#   'date': '2024-11-12',
#   'instructors': ['Renata Curty'],
#   'helpers': ['pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_5jBlh85uuXrM9kG"']},
#  {'href': '/workshop/2024/11/05/ucsb-webscraping.html',
#   'title_home': 'Web Scraping with Python',
#   'date': '2024-11-05',
#   'instructors': ['Jose Niño Muriel'],
#   'helpers': ['Noah Spahn', 'Ron Lencevičius', 'Seth Erickson']},
#  {'href': '/workshop/2024/10/22/ucsb-git.html',
#   'title_home': 'Version Control with Git and GitHub',
#   'date': '2024-10-22',
#   'instructors': ['Julien Brun',
#    'Seth Erickson',
#    'Jose Niño Muriel',
#    'Kristi Liu'],
#   'helpers': ['Amber Chen', 'Jay Chi', 'Renata Curty', 'Yuan Wu']},
#  {'href': '/workshop/2024/10/08/ucsb-r.html',
#   'title_home': 'Introduction to Data Analysis with R',
#   'date': '2024-10-08',
#   'instructors': ['Jose Niño Muriel',
#    'Greg Janée',
#    'Julien Brun',
#    'Renata Curty'],
#   'helpers': ['Jay Chi',
#    'Nandini Iyer',
#    'Seth Erickson',
#    'Sigrid Van Den Abbeele',
#    'Jon Jablonski']},
#  {'href': '/workshop/2024/09/09/UC.html',
#   'title_home': '2024 UC Carpentries Workshop Series (Remote)',
#   'date': '2024-09-09',
#   'instructors': ['Scott Peterson (UCB)',
#    'Reid Otsuji (UCSD)',
#    'Tim Dennis (UCLA)',
#    'Kim Thomas (UCSD)',
#    'Kaija Gahm (UCLA)',
#    'Jose Niño Muriel (UCSB)',
#    'Geoffrey Boushey (UCSF)',
#    'David Palmquist (CSU Fullerton)',
#    'Ken Howard (UCSB)'],
#   'helpers': ['Phredd Groves (UCSC)',
#    'Kristi Liu (UCSB)',
#    'Amber Xuqian Chen (UCSB)',
#    'Geno Sanchez (UCLA)',
#    'Stephanie Labou (UCSD)',
#    'Alejandra Sicairos (UCSB)',
#    'Leigh Phan (UCLA)',
#    'Monique Surles-Zeigler',
#    'Misha Coleman (UCB)',
#    'Derek Devnich (UC Merced)',
#    'Ken Howard (UCSB)',
#    'Echelle Burns (UCSB)',
#    'Xochitl Ortiz Ross (UCLA)',
#    'Allie Caughman (UCSB)']},
#  {'href': '/workshop/2024/09/05/SPNHC24.html',
#   'title_home': 'Data Carpentry: Species Interaction Data Workshop (Okinawa, Japan)',
#   'date': '2024-09-05',
#   'instructors': ['Kristi Liu'],
#   'helpers': ['pre_workshop_survey:']},
#  {'href': '/workshop/2024/07/09/ucsb-python.html',
#   'title_home': 'Data Analysis and Visualization in Python',
#   'date': '2024-07-09',
#   'instructors': ['Seth Erickson', 'Greg Janée', 'Jose Niño Muriel'],
#   'helpers': ['Kristi Liu']},
#  {'href': '/workshop/2024/07/02/ucsb-spreadsheets.html',
#   'title_home': 'Data Organization in Spreadsheets',
#   'date': '2024-07-02',
#   'instructors': ['Renata Curty', 'Jose Niño Muriel'],
#   'helpers': ['Jon Jablonski']},
#  {'href': '/workshop/2024/06/10/ucsb-geospatial.html',
#   'title_home': 'Introduction to Geospatial Raster and Vector Data with R',
#   'date': '2024-06-10',
#   'instructors': ['Julien Brun',
#    'Jon Jablonski',
#    'Kristi Liu',
#    'Jose Niño Muriel'],
#   'helpers': ['Patty Park']},
#  {'href': '/workshop/2024/06/04/ucsb-containers.html',
#   'title_home': 'Container-driven Reproducible Research Made Simple',
#   'date': '2024-06-04',
#   'instructors': ['Ronald Lencevičius'],
#   'helpers': ['Sang-Yun Oh', 'Jay Chi', 'Jose Niño Muriel']},
#  {'href': '/workshop/2024/05/01/ucsb-r.html',
#   'title_home': 'Introduction to Data Analysis with R for Social Science',
#   'date': '2024-05-01',
#   'instructors': ['Seth Erickson',
#    'Jon Jablonski',
#    'Greg Janée',
#    'Jose Niño Muriel',
#    'Donovan Rasamoelison'],
#   'helpers': ['Dave Hunter', 'Kristi Liu', 'Noah Spahn']},
#  {'href': '/workshop/2024/02/27/ucsb-webscraping.html',
#   'title_home': 'Introduction to Web Scraping',
#   'date': '2024-02-27',
#   'instructors': ['Renata Curty', 'Seth Erickson', 'Jose Niño Muriel'],
#   'helpers': ['Kristi Liu']},
#  {'href': '/workshop/2024/01/30/ucsb-git.html',
#   'title_home': 'Version Control with Git',
#   'date': '2024-01-30',
#   'instructors': ['Seth Erickson', 'Kristi Liu', 'Julien Brun'],
#   'helpers': ['Jose Niño Muriel']},
#  {'href': '/workshop/2023/12/11/ucsb-quarto.html',
#   'title_home': 'Reproducible Publications with Quarto',
#   'date': '2023-12-11',
#   'instructors': ['Renata Curty', 'Greg Janee'],
#   'helpers': ['Kristi Liu', 'Ian Lessing', 'Julien Brun']},
#  {'href': '/workshop/2023/11/13/ucsb-python.html',
#   'title_home': 'Data Analysis and Visualization in Python',
#   'date': '2023-11-13',
#   'instructors': ['Seth Erickson'],
#   'helpers': ['Kristi Liu']},
#  {'href': '/workshop/2023/10/23/ucsb-git.html',
#   'title_home': 'Version Control with Git',
#   'date': '2023-10-23',
#   'instructors': ['Seth Erickson', 'Greg Janée'],
#   'helpers': ['Kristi Liu', 'Julien Brun']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-07-28-ucsb-mcnairs-R/',
#   'title_home': 'What does it mean to be Reproducible in R?',
#   'date': '2023-07-28',
#   'instructors': ['Kristi Liu', 'Jon Jablonski'],
#   'helpers': ['Seth Erickson']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-05-16-ucsb-python/',
#   'title_home': 'Data Analysis and Visualization in Python',
#   'date': '2023-05-16',
#   'instructors': ['Seth Erickson', 'James Frew'],
#   'helpers': ['Kristi Liu', 'Jay Chi', 'Julien Brun']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-Planet-Labs/',
#   'title_home': 'Planet Labs Workshop',
#   'date': '2023-05-12',
#   'instructors': ['Kristi Liu', 'Jon Jablonski', 'Octave Lepinard'],
#   'helpers': ['Helper']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-MEDS-GIS/',
#   'title_home': 'Measure, Map, and Publish with ArcGIS Pro and Online',
#   'date': '2023-05-05',
#   'instructors': ['Kristi Liu', 'Jon Jablonski'],
#   'helpers': ['Helper']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-04-25-ucsb-git/',
#   'title_home': 'Introduction to Version Control with Git',
#   'date': '2023-04-25',
#   'instructors': ['Seth Erickson', 'Greg Janée', 'Kristi Liu'],
#   'helpers': ['Jon Jablonski', 'Julien Brun']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-02-21-python/',
#   'title_home': 'Intro to Data Analysis & Visualization in Python',
#   'date': '2023-02-21',
#   'instructors': ['Greg Janée', 'Seth Erickson', 'Isaac Park'],
#   'helpers': ['Kristi Liu', 'Jay Chi']},
#  {'href': 'https://ucsbcarpentry.github.io/2023-01-23-ucsb-r/',
#   'title_home': 'Mondays R for Social Science',
#   'date': '2023-01-23',
#   'instructors': ['Jon Jablonski', 'Renata Curty', 'Seth Erickson'],
#   'helpers': ['Kristi Liu', 'Amber Budden']},
#  {'href': ' https://ucsbcarpentry.github.io/2022-11-8-ucsb-reproducible-pubs/',
#   'title_home': 'Introduction to Reproducible Publications with RStudio',
#   'date': '2022-11-8',
#   'instructors': ['Renata Curty',
#    'Greg Janée',
#    'Seth Erickson',
#    'Ian Lessing',
#    'Jon Jablonski'],
#   'helpers': ['Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-10-25-ucsb-intro-R/',
#   'title_home': 'Data Analysis and Visualization in R',
#   'date': '2022-10-25',
#   'instructors': ['Greg Janée', 'Seth Erickson', 'Jon Jablonski'],
#   'helpers': ['Kristi Liu', 'Sam Csik', 'Jay Chi']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-10-18-ucsb-bash-git/',
#   'title_home': 'Introduction to the Unix Shell & Version Control with Git',
#   'date': '2022-10-18',
#   'instructors': ['Seth Erickson', 'Jon Jablonski'],
#   'helpers': ['Kristi Liu', 'Jay Chi']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-10-11-ucsb-spreadsheets/',
#   'title_home': 'Data Organization in Spreadsheets',
#   'date': '2022-10-11',
#   'instructors': ['Renata Curty', 'Greg Janée', 'Seth Erickson'],
#   'helpers': ['Kristi Liu']},
#  {'href': 'https://ucsdlib.github.io/2022-09-06-carpentries-uc/',
#   'title_home': 'UC Carpentries Fall 2022 Workshop Series',
#   'date': '2022-09-06',
#   'instructors': ['Scott Peterson (UCB)',
#    'Reid Otsuji (UCSD)',
#    'Kat Koziar (UCR)',
#    'Kimberly Thomas (UCSD)',
#    'Zhiyuan Yao (UCLA)',
#    'Christine Wells (UCLA)',
#    'Scott Gruber (UCLA)',
#    'Derek Devnich (UC Merced)',
#    'Erin Foster (UC Berkeley)',
#    'Kenji Hayashi (UCLA)',
#    'Ryan Gan (El Camino)'],
#   'helpers': ['Stephanie Labou (UCSD)',
#    'Reid Otsuji (UCSD)',
#    'Kristi Liu (UCSB)',
#    'Kat Koziar (UCR)',
#    'Kimberly Thomas (UCSD)',
#    'Lisa Ngo (UCB)',
#    'Leigh Phan (UCLA)',
#    'Eastern Kang (UCSD)']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-08-16-ucsb-machlearn-r/',
#   'title_home': 'Machine Learning for Tabular Data in R',
#   'date': '2022-08-16',
#   'instructors': ['Dave Hunter', 'Greg Janée'],
#   'helpers': ['Seth Erickson', 'Amanda Ho', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-08-09-ucsb-r-geospatial/',
#   'title_home': 'Intro to Geospatial Raster and Vector Data with R',
#   'date': '2022-08-09',
#   'instructors': ['Jon Jablonski', 'Seth Erickson', 'Kristi Liu'],
#   'helpers': ['Amanda Ho', 'Dave Hunter', 'Ezra Aguimatang', 'Greg Janee']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-07-26-ucsb-R/',
#   'title_home': 'Intro to Data Analysis and Visualization in R',
#   'date': '2022-07-26',
#   'instructors': ['Dave Hunter', 'Amanda Ho', 'Chris Kibler'],
#   'helpers': ['Kristi Liu', 'Seth Erickson']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-07-19-ucsb-git/',
#   'title_home': 'Version Control with Git',
#   'date': '2022-07-19',
#   'instructors': ['Seth Erickson', 'Kristi Liu', 'Amanda Ho'],
#   'helpers': ['TBD']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-07-12-ucsb-bash/',
#   'title_home': 'Intro to Bash-Shell',
#   'date': '2022-07-12',
#   'instructors': ['Seth Erickson', 'Amanda Ho', 'Kristi Liu', 'Jon Jablonski'],
#   'helpers': ['Brian Dincau']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-05-26-ucsb-twarc/',
#   'title_home': 'Harvesting Twitter with Twarc',
#   'date': '2022-05-26',
#   'instructors': ['Jon Jablonski', 'Kristi Liu', 'Amanda Ho'],
#   'helpers': ['Grace Nunnelley', 'Thao Phan', 'Amelia Meyer', 'Jingwei Wang']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-05-12-ucsb-webscraping/',
#   'title_home': 'Introduction to Webscraping',
#   'date': '2022-05-12',
#   'instructors': ['Renata Curty', 'Ryan Horne', 'Jon Jablonski', 'Greg Janée'],
#   'helpers': ['Amanda Ho', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-04-19-ucsb-python/',
#   'title_home': 'Data Analysis and Visualization in Python',
#   'date': '2022-04-19',
#   'instructors': ['Ryan Horne', 'Amanda Ho'],
#   'helpers': ['Kristi Liu', 'Amelia Meyer']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-04-14-ucsb-openrefine/',
#   'title_home': 'Intro to OpenRefine',
#   'date': '2022-04-14',
#   'instructors': ['Renata Curty', 'Jon Jablonski'],
#   'helpers': ['Amanda Ho', 'Greg Janee', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-04-11-ucsb-r-geospatial/',
#   'title_home': 'Intro to Geospatial Raster and Vector Data in R',
#   'date': '2022-04-11',
#   'instructors': ['Echelle Burns',
#    'Kristi Liu',
#    'Gavin McDonald',
#    'Jon Jablonski'],
#   'helpers': ['Amanda Ho']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-04-07-ucsb-r-geospatial/',
#   'title_home': 'Intro to Geospatial Raster and Vector Data in R',
#   'date': '2022-04-07',
#   'instructors': ['Echelle Burns',
#    'Jon Jablonski',
#    'Gavin McDonald',
#    'Kristi Liu'],
#   'helpers': ['Amanda Ho', 'Jason Flower', 'Amelia Meyer']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-03-03-ucsb-rstudio-reproducibility/',
#   'title_home': 'Reproducible Publications with RStudio',
#   'date': '2022-03-02',
#   'instructors': ['Renata Curty', 'Greg Janée', 'Ian Lessing', 'Torin White'],
#   'helpers': ['Echelle Burns', 'Amanda Ho', 'Kristi Liu', 'Amelia Meyers']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-02-24-ucsb-R-online/',
#   'title_home': 'Intro to R for Data Visualization',
#   'date': '2022-02-24',
#   'instructors': ['Amanda Ho', 'David Hunter', 'Jon Jablonski'],
#   'helpers': ['Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-02-15-ucsb-R-online/',
#   'title_home': 'SEEDS - Intro to R (SEEDS ONLY event)',
#   'date': '2022-02-15',
#   'instructors': ['Kristi Liu', 'Dave Hunter'],
#   'helpers': ['Susan Mazer', 'Amanda Ho', 'Jon Jablonski', 'Sara Orofino']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-02-07-ucsb-R-online/',
#   'title_home': 'SEEDS - Intro to R (SEEDS ONLY event)',
#   'date': '2022-02-07',
#   'instructors': ['Jon Jablonski'],
#   'helpers': ['Anita Carraher',
#    'Amanda Ho',
#    'Ryan Horne',
#    'Dave Hunter',
#    'Greg Janée',
#    'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-02-04-ucsb-sql-online/',
#   'title_home': 'Bren School MEDS - Relational Databases and SQL',
#   'date': '2022-02-04',
#   'instructors': ['Greg Janée', 'Amanda Ho'],
#   'helpers': ['Sam Csik', 'Kat Le', 'Jamie Montgomery', 'Amelia Meyer']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-01-31-ucsb-webpub-online/',
#   'title_home': 'Webpublishing with Github Pages (SEEDS ONLY event)',
#   'date': '2022-01-31',
#   'instructors': ['Jon Jablonski', 'Amanda Ho'],
#   'helpers': ['Amelia Meyer', 'Anita Carraher', 'Thao Phan', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-01-28-ucsb-webpub-online/',
#   'title_home': 'Webpublishing with Github Pages',
#   'date': '2022-01-28',
#   'instructors': ['Jon Jablonski', 'Amanda Ho'],
#   'helpers': ['Anita Carraher', 'Kristi Liu', 'Thao Phan']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-01-12-ucsb-gitbash/',
#   'title_home': 'SEEDS - Intro to Git/Bash Workshop (SEEDS event)',
#   'date': '2022-01-12',
#   'instructors': ['Amanda Ho', 'Jon Jablonski', 'Kristi Liu'],
#   'helpers': ['Jorge Murillo', 'Amelia Meyer', 'Thao Phan']},
#  {'href': 'https://ucsbcarpentry.github.io/2022-01-04-ucsb-python/',
#   'title_home': 'Bren School MEDS - Python Programming',
#   'date': '2022-01-04',
#   'instructors': ['Greg Janée', 'Amanda Ho'],
#   'helpers': ['Sam Csik', 'Kat Le', 'Kristi Liu', 'Jamie Montgomery']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-12-14-ucsb-gitbash-online/',
#   'title_home': 'Intro to Git/Bash Workshop',
#   'date': '2021-12-14',
#   'instructors': ['Kristi Liu', 'Renata Curty', 'Jon Jablonski'],
#   'helpers': ['Anita Carraher',
#    'Amanda Ho',
#    'Annie Huang',
#    'Connor Levenson',
#    'Amelia Meyers']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-11-04-ucsb-sql-online/',
#   'title_home': 'Software Carpentry: Intro to SQL and Relational Databases',
#   'date': '2021-11-04',
#   'instructors': ['Jon Jablonski', 'Kristi Liu', 'Greg Janee', 'Amanda Ho'],
#   'helpers': ['Ian Lessing', 'Kat Le', 'Connor Levenson']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-10-19-ucsb-python-online/',
#   'title_home': 'Data Carpentry: Intro to Python',
#   'date': '2021-10-19',
#   'instructors': ['Greg Janee', 'Isaac Park', 'Ian Lessing'],
#   'helpers': ['Jean Allen',
#    'Melanie Leung',
#    'Jon Jablonski',
#    'Kristi Liu',
#    'Amanda Ho']},
#  {'href': 'https://ucsdlib.github.io/2021-09-13-uc-collab/',
#   'title_home': '2021 UC Fall Workshop',
#   'date': '2021-09-13',
#   'instructors': ['Scott Peterson (UCB)',
#    'Reid Otsuji (UCSD)',
#    'Stephanie Labou (UCSD)',
#    'Kat Koziar (UCR)',
#    'Kimberly Thomas (UCSD)',
#    'Harry Zhou (UCSD)',
#    'Jamie Jamison (UCLA)',
#    'Kristian Allen (UCLA)',
#    'Zhiyuan Yao (UCLA)',
#    'Leigh Phan (UCLA)',
#    'Maddi Cowen (UCLA)',
#    'Lisa McAulay (UCLA)',
#    'Dave George (UCLA)',
#    'Anna Sackmann (UCB)',
#    'Erin Foster (UCB)',
#    'David Palmquist (CSU Fullerton)',
#    'Mark Matney (UCLA)',
#    'Alexandre de Siqueira (UCB)'],
#   'helpers': ['Stephanie Labou (UCSD)',
#    'Reid Otsuji (UCSD)',
#    'Tim Dennis (UCLA)',
#    'Kat Koziar (UCR)',
#    'Scott Peterson (UCB)',
#    'Alexandre de Siqueira (UCB)',
#    'Kimberly Thomas (UCSD)',
#    'Harry Zhou (UCSD)',
#    'Reza Monadi (UCR)',
#    'Anna Sackmann (UCB)',
#    'Erin Foster (UCB)',
#    'Lisa Ngo (UCB)',
#    'Sam Teplitzky (UCB)',
#    'Mark Matney (UCLA)',
#    'Kristi Liu (UCSB)']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-08-11-ucsb-git-online/',
#   'title_home': 'Intro to Version Control with Git',
#   'date': '2021-08-11',
#   'instructors': ['Kristi Liu', 'Jon Jablonski'],
#   'helpers': ['Renata Curty', 'Greg Janee']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-08-09-ucsb-bash-online/',
#   'title_home': 'Intro to Bash-Shell',
#   'date': '2021-08-09',
#   'instructors': ['Kristi Liu', 'Jon Jablonski'],
#   'helpers': ['Renata Curty', 'Reid Otsuji']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-08-16-ucsb-introR-online/',
#   'title_home': 'Intro to R',
#   'date': '2021-08-16',
#   'instructors': ['Jon Jablonski', 'Britta Schumacher'],
#   'helpers': ['Kristi Liu', 'Amelia Meyer', 'Melanie Leung']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-08-23-ucsb-python-online/',
#   'title_home': 'Intro to Python',
#   'date': '2021-08-23',
#   'instructors': ['Greg Janee', 'Ian Lessing', 'Dave Hunter'],
#   'helpers': ['Kristi Liu',
#    'Renata Curty',
#    'Amelia Meyer',
#    'David Palmquist',
#    'Isaac Park']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-05-13-GeospatialR/',
#   'title_home': 'R for GeoSpatial',
#   'date': '2021-05-12',
#   'instructors': ['Jon Jablonski',
#    'Kristi Liu',
#    "Casey O'Hara",
#    'Britta Schumacher',
#    'Echelle Burns'],
#   'helpers': ['Kristi Liu',
#    "Casey O'Hara",
#    'Dave Hunter',
#    'Juliano Palacios']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-05-06-IntroR/',
#   'title_home': 'Intro to R',
#   'date': '2021-05-06',
#   'instructors': ['Torin White', 'Camila Vargas-Poulsen', 'Greg Janee'],
#   'helpers': ['Kristi Liu', 'Renata Curty', 'Amelia Meyer', 'Ian Lessing']},
#  {'href': 'https://annajiat.github.io/2021-04-16-merced-online/',
#   'title_home': 'UC Merced Library Carpentry for Humanists and Social Scientists',
#   'date': '2021-04-16',
#   'instructors': ['Jon Jablonski',
#    'Annajiat Alim Rasel',
#    'Andrea Medina-Smith'],
#   'helpers': ['Lesly Lopez', 'Jasper Toscani Field', 'Henry Stokes']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-02-18-ucsb-online/',
#   'title_home': 'Data Carpentry: Ecology with Python',
#   'date': '2021-02-18',
#   'instructors': ['Elnaz Amanzadeh Jajin', 'Rohit Goswami'],
#   'helpers': ['Austin Covey',
#    'Sanjeev Kolli',
#    'PK Kottapalli',
#    'Qiancheng Zhao',
#    'Kristi Liu',
#    'Jon Jablonski',
#    'Ian Lessing']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-01-22-SWC-Git-online/',
#   'title_home': 'Intro to Version Control with Git',
#   'date': '2021-01-22',
#   'instructors': ['Kristi Liu', 'Torin White', 'Jon Jablonski'],
#   'helpers': ['Renata Curty', 'Ian Lessing']},
#  {'href': 'https://ucsbcarpentry.github.io/2021-01-21-SWC-Bash-online/',
#   'title_home': 'Intro to Bash Shell',
#   'date': '2021-01-21',
#   'instructors': ['Torin White', 'Sanjeev Kolli', 'Ian Lessing', 'Greg Janee'],
#   'helpers': ['Kristi Liu', 'PK Kottapalli']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-12-16-Rmarkdown-UCSB-online/',
#   'title_home': 'Authoring Scientific Publications with R-Markdown',
#   'date': '2020-12-16',
#   'instructors': ['Torin White', 'Renata Curty', 'Greg Janee', 'Kristi Liu'],
#   'helpers': ['Jon Jablonski', 'Ian Lessing']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-11-09-OpenRefine-online/',
#   'title_home': 'Open Refine Libary Carpentry',
#   'date': '2020-11-09',
#   'instructors': ['Jon Jablonski', 'Torin White', 'Renata Curty'],
#   'helpers': ['Kristi Liu', 'Serena Osmuss']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-10-09-ReprodR-online/',
#   'title_home': 'R programming for Scientific Reproducibility',
#   'date': '2020-10-09',
#   'instructors': ['Torin White',
#    'Camila Vargas-Poulsen',
#    'Renata Curty',
#    'Greg Janee'],
#   'helpers': ['Kristi Liu', 'Ian Lessing']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-08-19-Summer-Python/',
#   'title_home': 'Introduction to Python',
#   'date': '2020-08-19',
#   'instructors': ['Kristi Liu', 'Sanjeev Kolli', 'Ian Lessing', 'Torin White'],
#   'helpers': ['Qiancheng Zhao', 'Jon Jablonski', 'Sharon Solis']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-08-19-Summer-Python/',
#   'title_home': 'Introduction to Python',
#   'date': '2020-08-19',
#   'instructors': ['Kristi Liu', 'Sanjeev Kolli', 'Ian Lessing', 'Torin White'],
#   'helpers': ['Qiancheng Zhao', 'Jon Jablonski', 'Sharon Solis']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-08-17-Summer-R/',
#   'title_home': 'Intro to R programming',
#   'date': '2020-08-17',
#   'instructors': ['Rob Levenson', 'Jon Jablonski', 'Torin White'],
#   'helpers': ['Torin White', 'Kristi Liu', 'Sharon Solis', 'Mireia Valle']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-08-17-Summer-R/',
#   'title_home': 'Intro to R programming',
#   'date': '2020-08-17',
#   'instructors': ['Rob Levenson', 'Jon Jablonski', 'Torin White'],
#   'helpers': ['Torin White', 'Kristi Liu', 'Sharon Solis', 'Mireia Valle']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-08-10-Summer-GitBash/',
#   'title_home': 'Intro to Bash & Git',
#   'date': '2020-08-10',
#   'instructors': ['Torin White',
#    'Sanjeev Kolli',
#    'Greg Janee',
#    'Ian Lessing',
#    'Renata Curty'],
#   'helpers': ['Kristi Liu', 'Sharon Solis', 'Jon Jablonski']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-06-03-UCSB-LibCarp/',
#   'title_home': 'Bash & Webscraping',
#   'date': '2020-06-03',
#   'instructors': ['Torin White',
#    'Sanjeev Kolli',
#    'Renata Curty',
#    'Kristi Liu',
#    'Jon Jablonski',
#    'Greg Janee'],
#   'helpers': ['Kristi Liu', 'Torin White']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-05-29-UCSB-R/',
#   'title_home': 'Intro to R Programming',
#   'date': '2020-05-29',
#   'instructors': ['Jon Jablonski',
#    'Greg Janee',
#    'Li Kui',
#    'Mary Donovan',
#    'Rob Levenson'],
#   'helpers': ['Torin White',
#    'Ian Lessing',
#    'Kristi Liu',
#    'Sanjeev Kolli',
#    'Renata Curty',
#    'Mireia Valle',
#    'Camila Vargas-Poulsen']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-01-31-UCSB-SQL/',
#   'title_home': 'Databases and SQL',
#   'date': '2020-01-31',
#   'instructors': ['Greg Janée', 'Ian Lessing', 'Jon Jablonski', 'Zach Sisco'],
#   'helpers': ['Torin White', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-01-17-UCSB-bash/',
#   'title_home': 'Introduction to the Unix Shell',
#   'date': '2020-01-17',
#   'instructors': ['Jon Jablonski', 'Yuan Wu'],
#   'helpers': ['Torin White', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2020-01-17-UCSB-git/',
#   'title_home': 'Version Control with Git',
#   'date': '2020-01-17',
#   'instructors': ['Jon Jablonski', 'Yuan Wu', 'Kristi Liu'],
#   'helpers': ['Torin White', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-11-14-Geospatial-R/',
#   'title_home': 'R for Geospatial Data',
#   'date': '2019-11-14',
#   'instructors': ['Ryan Avery', 'Jon Jablonski', 'Mary Donovan'],
#   'helpers': ['Kristi Liu', 'Fernanda Ribeiro', 'Yuan Wu']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-10-24-gitbash/',
#   'title_home': 'Git & Bash',
#   'date': '2019-10-24',
#   'instructors': ['Jon Jablonski', 'Ian Lessing', 'Yuan Wu', 'Zach Sisco'],
#   'helpers': ['Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-10-10-Python-UCSB/',
#   'title_home': 'Plotting and Programming in Python',
#   'date': '2019-10-10',
#   'instructors': ['Greg Janée', 'Yuan Wu', 'Ian Lessing', 'Sanjeev Kolli'],
#   'helpers': ['Kristi Liu', 'Jon Jablonski', 'Sharon Solis']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-summer/',
#   'title_home': 'Summer Python Class',
#   'date': '2019-06-25',
#   'instructors': ['Sharon Solis', 'Ian Lessing', 'Vania Wang', 'Noah Spahn'],
#   'helpers': []},
#  {'href': 'https://ucsbcarpentry.github.io/2019-05-09-UCSB-SW-Carpentry/',
#   'title_home': 'Bash, Git & Python Workshop',
#   'date': '2019-05-09',
#   'instructors': ['Ryan Avery',
#    'Sharon Solis',
#    'Greg Janée',
#    'Ian Lessing',
#    'Yuan Wu',
#    'Jon Jablonski'],
#   'helpers': ['Noah Spahn', 'Vania Wang']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-04-11-UCSB-SW-Workshop/',
#   'title_home': 'Bash, Git & R Workshop',
#   'date': '2019-04-11',
#   'instructors': ['Jon Jablonski',
#    'Ian Lessing',
#    'Greg Janee',
#    'Sharon Solis',
#    'Mary Donovan',
#    'Yuan Wu'],
#   'helpers': ['Noah Spahn', 'Kristi Liu']},
#  {'href': 'https://ucsbcarpentry.github.io/2019-03-21-UCSBLibrary/',
#   'title_home': 'Bash, Git & R',
#   'date': '2019-03-21',
#   'instructors': ['Jon Jablonski',
#    'Ian Lessing',
#    'Greg Janee',
#    'Sharon Solis',
#    'Mary Donovan',
#    'Yuan Wu'],
#   'helpers': []},
#  {'href': 'https://ucsbcarpentry.github.io/2019-02-21-UCSBLibrary/',
#   'title_home': 'Bash, Git & R',
#   'date': '2019-02-21',
#   'instructors': ['Jon Jablonski',
#    'Ian Lessing',
#    'Greg Janee',
#    'Sharon Solis',
#    'Mary Donovan',
#    'Yuan Wu'],
#   'helpers': []},
#  {'href': 'https://ucsbcarpentry.github.io/2019-01-25-UCSBLibrary/',
#   'title_home': 'Bash, Git & R',
#   'date': '2019-01-25',
#   'instructors': ['Jon Jablonski',
#    'Ian Lessing',
#    'Greg Janee',
#    'Sharon Solis',
#    'Mary Donovan',
#    'Katja Seltmann',
#    'Yuan Wu'],
#   'helpers': []},
#  {'href': 'http://remi-daigle.github.io/2016-04-15-UCSB/',
#   'title_home': 'R Programming Language',
#   'date': [],
#   'instructors': [],
#   'helpers': []},
#  {'href': 'http://remi-daigle.github.io/2016-04-15-UCSB/',
#   'title_home': 'R Programming Language',
#   'date': [],
#   'instructors': [],
#   'helpers': []}]

# %%
# Check for names written in different ways

# Initialize an empty set to collect unique names
unique_names = set()

# Iterate over each dictionary in the list
for workshop in wlist:
    # Add all instructors and helpers to the set
    unique_names.update(workshop['instructors'])
    unique_names.update(workshop['helpers'])

# Convert the set back to a list
unique_names_list = sorted(list(unique_names))

print(unique_names_list)
# Out:
# ['Alejandra Sicairos (UCSB)', 'Alexandre de Siqueira (UCB)', 'Allie Caughman', 'Amanda Ho', 'Amber Budden', 'Amber Chen', 'Amelia Meyer', 'Andrea Medina-Smith', 'Anita Carraher', 'Anna Sackmann (UCB)', 'Annajiat Alim Rasel', 'Annie Huang', 'Arieanna Balbar', 'Austin Covey', 'Brian Dincau', 'Brian Emery', 'Britta Schumacher', 'Camila Vargas-Poulsen', "Casey O'Hara", 'Chris Kibler', 'Christine Wells (UCLA)', 'Connor Levenson', 'Dave George (UCLA)', 'Dave Hunter', 'David Palmquist', 'David Palmquist (CSU Fullerton)', 'Derek Devnich (UC Merced)', 'Donovan Rasamoelison', 'Eastern Kang (UCSD)', 'Echelle Burns', 'Elnaz Amanzadeh Jajin', 'Erin Foster (UC Berkeley)', 'Erin Foster (UCB)', 'Ezra Aguimatang', 'Fernanda Ribeiro', 'Gavin McDonald', 'Geno Sanchez (UCLA)', 'Geoffrey Boushey (UCSF)', 'Grace Nunnelley', 'Greg Janée', 'Harry Zhou (UCSD)', 'Helper', 'Henry Stokes', 'Ian Lessing', 'Isaac Park', 'Jairo Melo-Flórez', 'James Frew', 'Jamie Jamison (UCLA)', 'Jamie Montgomery', 'Jason Flower', 'Jasper Toscani Field', 'Jay Chi', 'Jean Allen', 'Jingwei Wang', 'Jon Jablonski', 'Jorge Murillo', 'Jose Niño Muriel', 'Juliano Palacios', 'Julien Brun', 'Kaija Gahm (UCLA)', 'Kat Koziar (UCR)', 'Kat Le', 'Katja Seltmann', 'Ken Howard (UCSB)', 'Kenji Hayashi (UCLA)', 'Kim Thomas (UCSD)', 'Kimberly Thomas (UCSD)', 'Kinji Leslie', 'Kristi Liu', 'Kristian Allen (UCLA)', 'Leigh Phan (UCLA)', 'Lesly Lopez', 'Li Kui', 'Lisa McAulay (UCLA)', 'Lisa Ngo (UCB)', 'Maddi Cowen (UCLA)', 'Mark Matney (UCLA)', 'Mary Donovan', 'Melanie Leung', 'Mireia Valle', 'Misha Coleman (UCB)', 'Monique Surles-Zeigler', 'Nandini Iyer', 'Noah Spahn', 'Octave Lepinard', 'PK Kottapalli', 'Patty Park', 'Phredd Groves (UCSC)', 'Qiancheng Zhao', 'Reid Otsuji', 'Reid Otsuji (UCSD)', 'Renata Curty', 'Reza Monadi (UCR)', 'Rob Levenson', 'Rohit Goswami', 'Ronald Lencevičius', 'Ryan Avery', 'Ryan Gan (El Camino)', 'Ryan Horne', 'Sam Csik', 'Sam Teplitzky (UCB)', 'Sang-Yun Oh', 'Sanjeev Kolli', 'Sara Orofino', 'Scott Gruber (UCLA)', 'Scott Miller', 'Scott Peterson (UCB)', 'Serena Osmuss', 'Seth Erickson', 'Sharon Solis', 'Sigrid Van Den Abbeele', 'Stephanie Labou (UCSD)', 'Susan Mazer', 'TBD', 'Tess Ivinjack', 'Thao Phan', 'Tim Dennis (UCLA)', 'Torin White', 'Vania Wang', 'Xochitl Ortiz Ross (UCLA)', 'Yuan Wu', 'Zach Sisco', 'Zhiyuan Yao (UCLA)', 'pre_workshop_survey:', 'pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_1zu1a9eHmqQPR9c"', 'pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_5jBlh85uuXrM9kG"']

# %%
# We see that we should replace "David Hunter" for "Dave Hunter" and "Greg Janee" for "Greg Janée"
for workshop in wlist:
    workshop['instructors'] = ['Dave Hunter' if name == 'David Hunter' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Dave Hunter' if name == 'David Hunter' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Greg Janée' if name == 'Greg Janee' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Greg Janée' if name == 'Greg Janee' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Kristi Liu' if name == 'Kristi Liu (UCSB)' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Kristi Liu' if name == 'Kristi Liu (UCSB)' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Amelia Meyer' if name == 'Amelia Meyers' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Amelia Meyer' if name == 'Amelia Meyers' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Amber Chen' if name == 'Amber Xuqian Chen (UCSB)' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Amber Chen' if name == 'Amber Xuqian Chen (UCSB)' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Allie Caughman' if name == 'Allie Caughman (UCSB)' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Allie Caughman' if name == 'Allie Caughman (UCSB)' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Echelle Burns' if name == 'Echelle Burns (UCSB)' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Echelle Burns' if name == 'Echelle Burns (UCSB)' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Jose Niño Muriel' if name == 'Jose Nino Muriel' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Jose Niño Muriel' if name == 'Jose Nino Muriel' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Jose Niño Muriel' if name == 'Jose Niño Muriel (UCSB)' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Jose Niño Muriel' if name == 'Jose Niño Muriel (UCSB)' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Ronald Lencevičius' if name == 'Ron Lencevičius' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Ronald Lencevičius' if name == 'Ron Lencevičius' else name for name in workshop['helpers']]
    workshop['instructors'] = ['Sigrid Van Den Abbeele' if name == 'Sigrid Van Den Abeele' else name for name in workshop['instructors']]
    workshop['helpers'] = ['Sigrid Van Den Abbeele' if name == 'Sigrid Van Den Abeele' else name for name in workshop['helpers']]

# %%
data = []
for workshop in wlist:
    row = {
        'date': workshop['date'],
        'title_home': workshop['title_home']
    }
    for helper in workshop['helpers']:
        row[helper] = 'helper'
    for instructor in workshop['instructors']:
        row[instructor] = 'instructor'
    data.append(row)

df = pd.DataFrame(data)

# Step 2: Replace NaN with empty strings
df = df.fillna('')

# Step 3: Get the list of all columns except 'date' and 'wname'
columns = df.columns.tolist()
fixed_columns = ['date', 'title_home']
name_columns = sorted([col for col in columns if col not in fixed_columns])

# Step 4: Reorder the DataFrame columns
df = df[fixed_columns + name_columns]

# %%
df
# Out:
#           date                                         title_home  \
# 0   2025-02-25         Introduction to Machine Learning in Python
# 1   2025-02-18                                     Intermediate R
# 2   2025-02-05  Container-driven Reproducible Research Made Si...
# 3   2025-02-03  Research Computing - What to do when your work...
# 4   2025-01-23                  Working with Geospatial Data in R
# ..         ...                                                ...
# 87  2019-03-21                                      Bash, Git & R
# 88  2019-02-21                                      Bash, Git & R
# 89  2019-01-25                                      Bash, Git & R
# 90          []                             R Programming Language
# 91          []                             R Programming Language
#
#    Alejandra Sicairos (UCSB) Alexandre de Siqueira (UCB) Allie Caughman  \
# 0
# 1
# 2
# 3
# 4                                                            instructor
# ..                       ...                         ...            ...
# 87
# 88
# 89
# 90
# 91
#
#    Amanda Ho Amber Budden Amber Chen Amelia Meyer Andrea Medina-Smith  ...  \
# 0                                                                      ...
# 1                                                                      ...
# 2                                                                      ...
# 3                                                                      ...
# 4                                                                      ...
# ..       ...          ...        ...          ...                 ...  ...
# 87                                                                     ...
# 88                                                                     ...
# 89                                                                     ...
# 90                                                                     ...
# 91                                                                     ...
#
#    Tim Dennis (UCLA) Torin White Vania Wang Xochitl Ortiz Ross (UCLA)  \
# 0
# 1
# 2
# 3
# 4
# ..               ...         ...        ...                       ...
# 87
# 88
# 89
# 90
# 91
#
#        Yuan Wu Zach Sisco Zhiyuan Yao (UCLA) pre_workshop_survey:  \
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...                ...                  ...
# 87  instructor
# 88  instructor
# 89  instructor
# 90
# 91
#
#    pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_1zu1a9eHmqQPR9c"  \
# 0
# 1
# 2
# 3                                              helper
# 4
# ..                                                ...
# 87
# 88
# 89
# 90
# 91
#
#    pre_workshop_survey: "https://ucsb.co1.qualtrics.com/jfe/form/SV_5jBlh85uuXrM9kG"
# 0
# 1
# 2
# 3
# 4
# ..                                                ...
# 87
# 88
# 89
# 90
# 91
#
# [92 rows x 128 columns]

# %%
df2 = df.drop(columns=['date', 'title_home'])
# Melt the dataframe to long format
df_melted = df2.reset_index().melt(id_vars='index', var_name='Name', value_name='Role')

# Remove empty roles
df_melted = df_melted[df_melted['Role'] != '']

# Add date and title columns back to the melted dataframe
df_melted = df_melted.merge(df[['date', 'title_home']].reset_index(), on='index', how='left')
df_melted.drop(columns=['index'], inplace=True)

# Count roles for each person
role_counts = df_melted.pivot_table(index='Name', columns='Role', aggfunc='size', fill_value=0)
role_counts['Total'] = role_counts.sum(axis=1)
role_counts = role_counts.reset_index()

# Find the last workshop details for each person
last_workshop = df_melted.sort_values(by='date').groupby('Name').last().reset_index()

# Merge the last workshop details with role_counts
final_result = role_counts.merge(last_workshop[['Name', 'date', 'title_home', 'Role']], on='Name', how='left')

# Rename columns for clarity
final_result.rename(columns={'date': 'Last_Workshop_Date', 'title_home': 'Last_Workshop_Title', 'Role': 'Last_Workshop_Role'}, inplace=True)

# %%
final_result
# Out:
#                                                   Name  helper  instructor  \
# 0                            Alejandra Sicairos (UCSB)       1           0
# 1                          Alexandre de Siqueira (UCB)       0           1
# 2                                       Allie Caughman       1           1
# 3                                            Amanda Ho      11          12
# 4                                         Amber Budden       1           0
# ..                                                 ...     ...         ...
# 121                                         Zach Sisco       0           2
# 122                                 Zhiyuan Yao (UCLA)       0           2
# 123                               pre_workshop_survey:       1           0
# 124  pre_workshop_survey: "https://ucsb.co1.qualtri...       1           0
# 125  pre_workshop_survey: "https://ucsb.co1.qualtri...       1           0
#
#      Total Last_Workshop_Date  \
# 0        1         2024-09-09
# 1        1         2021-09-13
# 2        2         2025-01-23
# 3       23         2022-08-16
# 4        1         2023-01-23
# ..     ...                ...
# 121      2         2020-01-31
# 122      2         2022-09-06
# 123      1         2024-09-05
# 124      1         2025-02-03
# 125      1         2024-11-12
#
#                                    Last_Workshop_Title Last_Workshop_Role
# 0         2024 UC Carpentries Workshop Series (Remote)             helper
# 1                                2021 UC Fall Workshop         instructor
# 2                    Working with Geospatial Data in R         instructor
# 3               Machine Learning for Tabular Data in R             helper
# 4                         Mondays R for Social Science             helper
# ..                                                 ...                ...
# 121                                  Databases and SQL         instructor
# 122           UC Carpentries Fall 2022 Workshop Series         instructor
# 123  Data Carpentry: Species Interaction Data Works...             helper
# 124  Research Computing - What to do when your work...             helper
# 125  Handling and Sharing Qualitative Data Responsi...             helper
#
# [126 rows x 7 columns]

# %%
# Save to excel
with pd.ExcelWriter('ucsb_workshops_list.xlsx', engine='xlsxwriter') as writer:
    # Write each dataframe to a different worksheet
    df.to_excel(writer, sheet_name='comp_wkshp_instr', index=False)
    final_result.to_excel(writer, sheet_name='summary_instr', index=False)
