# %%
import pandas as pd

# %%
data = pd.read_excel('Instruction-data.xlsx')

# %%
carp = data.loc[data['Course department'] == 'Carpentry Workshop', :]

# %%
carp
# Out:
#           Submitted Time     Librarian name Multiple library instructors?  \
# 3    2024-07-23 15:28:00      Curty, Renata                           Yes
# 4    2024-07-23 15:28:00     Jablonski, Jon                           Yes
# 5    2024-07-23 15:28:00        Janée, Greg                           Yes
# 6    2024-07-23 15:28:00  Niño Muriel, Jose                           Yes
# 7    2024-07-23 15:28:00     Erickson, Seth                           NaN
# ...                  ...                ...                           ...
# 1062                 NaT       Lessing, Ian                           NaN
# 1063                 NaT     Jablonski, Jon                           NaN
# 1064                 NaT     Jablonski, Jon                           NaN
# 1065                 NaT     Jablonski, Jon                           NaN
# 1066                 NaT     Jablonski, Jon                           NaN
#
#                                                   Email Faculty or Instructor  \
# ...
